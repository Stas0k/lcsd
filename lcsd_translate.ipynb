# %% [markdown]
# # <span style="color: #4daafc">Legal Case Similarity Detection - Translate legal documents</span>
# - [Load Data](#load-data)
# - [Trasnslate Hebrew to English](#translate-hebrew-to-english)
# - [Save translated data](#save-translated-data)

# %% [markdown]
# # Prepare python environment

# %%
from utils.file_utils import load_file, save_file
from utils.df import df_shape
import tiktoken
import numpy as np
import pandas as pd
from langchain_ollama.llms import OllamaLLM
from langchain_community.document_loaders import DataFrameLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_ollama import OllamaEmbeddings
import faiss
from langchain_community.vectorstores import FAISS 
from langchain_community.docstore.in_memory import InMemoryDocstore
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
from sklearn.preprocessing import MultiLabelBinarizer
import ast
import re

# %% [markdown]
# # Load Data

# %%
f_path = 'data/processed_data_ar_ap_100.xlsx'
df = load_file(file_name=f_path)
# Out:
# Successfully loaded DataFrame from data/processed_data_ar_ap_100.xlsx

# %%
df_shape(df)
display(df.head(10))
# Out:
# Data shape: 100 rows x 5 columns
#   case_number                                     procedure_name   case_date  \
# 0     1108/97              ע"א 1108/97 מרחיב אביב נ. מדינת ישראל  1997-05-11
# 1     4477/00  ע"א 4477/00 לודמילה וורוביוב נ. היועצ המשפטי ל...  2000-07-06
# 2     1890/16                                        ע"פ 1890/16  2017-03-09
# 3     7176/04               ע"פ 7176/04 ירונ תלמי נ. מדינת ישראל  2006-02-02
# 4     3766/12                                        ע"א 3766/12  2012-06-17
# 5     8178/12          ע"א 8178/12 עו"ד צבי סלנט נ. יונתנ גוטליב  2014-11-12
# 6     3015/09               ע"פ 3015/09 מדינת ישראל נ. פואד קדיח  2010-07-20
# 7     4272/05             ע"פ 4272/05 אמיר חג'וג' נ. מדינת ישראל  2006-01-04
# 8    10467/08         ע"א 10467/08 עומר חג'אזי נ. אדיב עיסא דיאב  2010-11-03
# 9     3330/11  ע"א 3330/11 אגד אגודה שיתופית לתחבורה בישראל ב...  2011-11-17
#
#                                            case_link  \
# 0  https://supremedecisions.court.gov.il/Verdicts...
# 1  https://supremedecisions.court.gov.il/Verdicts...
# 2  https://supremedecisions.court.gov.il/Verdicts...
# 3  https://supremedecisions.court.gov.il/Verdicts...
# 4  https://supremedecisions.court.gov.il/Verdicts...
# 5  https://supremedecisions.court.gov.il/Verdicts...
# 6  https://supremedecisions.court.gov.il/Verdicts...
# 7  https://supremedecisions.court.gov.il/Verdicts...
# 8  https://supremedecisions.court.gov.il/Verdicts...
# 9  https://supremedecisions.court.gov.il/Verdicts...
#
#                                        document_body
# 0  בבית המשפט העליון בש"פ 97 / 1108 בפני: כבוד הר...
# 1  בבית המשפט העליון בה"נ 4477/00 בפני כבוד נשיא ...
# 2  פסק דין בתיק ע"פ 1890/16 בבית המשפט העליון בשב...
# 3  פסק-דין בתיק ע"פ 7176/04 בבית המשפט העליון בשב...
# 4  החלטה בתיק ע"א 3766/12 בבית המשפט העליון בירוש...
# 5  החלטה בתיק ע"א 8178/12 בבית המשפט העליון בשבתו...
# 6  פסק דין בתיק ע"פ 3015/09 בבית המשפט העליון בשב...
# 7  פסק-דין בתיק ע"פ 4272/05 בבית המשפט העליון בשב...
# 8  פסק דין בתיק ע"א 10467/08 בבית המשפט העליון בש...
# 9  פסק דין בתיק ע"א 3330/11 בבית המשפט העליון בשב...

# %% [markdown]
# # Translate Hebrew to English

# %%
base_url = "http://localhost:11434"
translation_model = 'dictalm2.0-instruct:f16'

# %% [markdown]
# ### Number of tokens estimated by GPT-4o-mini

# %%
encoding = tiktoken.encoding_for_model("gpt-4o-mini")

# %% [markdown]
# ### Define translation chain

# %%
translation_prompt = PromptTemplate(
    input_variables=["text"],
    template="""Translate the following Hebrew text to English. Provide a complete, word-for-word translation without summarizing. Respond only in English.\n\n
    Hebrew: {text}
    English: 
    """
)

translation_llm = OllamaLLM(base_url=base_url, model=translation_model, temperature=0.0, num_predict=3072, num_ctx=8192)

translation_chain = translation_prompt | translation_llm

# %%
def split_df_column(df, col, max_length=32767):
    """Splits a column with long text into multiple columns."""
    
    def split_long_text(text, max_length):
        """Splits long text into chunks."""
        return [text[i:i + max_length] for i in range(0, len(text), max_length)]
    
    # Create a copy of the DataFrame to avoid modifying the original
    df_copy = df.copy()

    # Iterate over each row in the DataFrame
    for idx, row in df_copy.iterrows():
        long_text = row[col]
        # Split the text into smaller parts
        chunks = split_long_text(long_text, max_length)
        # Add the chunks as new columns
        for i, chunk in enumerate(chunks):
            df_copy.at[idx, f'{col}_{i+1}'] = chunk

    return df_copy

def split_to_sentences(text):
    """
    Splitts the text into sentences. Delimiters are . or ? or !.
    """
    # regex pattern for sentence boundaries (., ?, !)
    pattern = r'(?<=[.?!])\s+'
    # split text by the pattern
    sentences = re.split(pattern, text)
    return [sentence.strip() for sentence in sentences if sentence.strip()]

def split_to_paragraphs(text):
    # This regular expression looks for a number (with more than one digit) or a Hebrew letter followed by a dot and space
    pattern = r'(?<=\. )([0-9]{1,2}|[א-ת])\.\s'
    
    # Split the text into paragraphs by matching the pattern
    paragraphs = re.split(pattern, text)
    
    # Add the first part of each split back as a paragraph, and keep the dot and space after the number/letter
    paragraphs = [paragraphs[0]] + [paragraphs[i] + ". " + paragraphs[i + 1] for i in range(1, len(paragraphs), 2)]
    
    return paragraphs

def count_tokens(text):
    return len(encoding.encode(text))

def split_text(text, max_tokens=512):
    """
    The functions spiltes the text in chunks of max 512 tokens, without breaking the sentence into 2 separate chunks.
    """
    # split the text into paragraphs
    paragraphs = split_to_paragraphs(text)
    chunks = []
    current_chunk = ""

    for paragraph in paragraphs:
        # if the paragraph is smaller than max_tokens, add it directly
        if count_tokens(paragraph) <= max_tokens:
            chunks.append(paragraph)
        else:
            # split paragraph into sentences
            sentences = split_to_sentences(paragraph)

            current_chunk = ""
            for sentence in sentences:
                
                # check if adding the current sentence would exceed the max token limit
                if len(encoding.encode(current_chunk + sentence)) > max_tokens:
                    # if it does, finalize the current chunk and start a new one
                    chunks.append(current_chunk.strip())
                    current_chunk = sentence + " "
                else:
                    # otherwise, add the sentence to the current chunk
                    current_chunk += sentence + " "
    
            # add the last chunk if it's not empty
            if current_chunk:
                chunks.append(current_chunk.strip())
            
    return chunks

def translate_text(i_text):
    """
    Translates the input text by invoking the translation chain. In the end - non-necessary charaters are removed.
    """
    chunks = split_text(i_text)
    translations = [translation_chain.invoke({"text": c}) for c in chunks]
    res = ' '.join(translations)
    res = res.strip()
    res = re.sub(r'\n+', ' ', res)
    return res

# %%
# apply the translation function to 'document_body' column
df_translated = df.copy()
df_translated['document_body_english'] = df_translated['document_body'].apply(translate_text)

# %%
df_translated['document_body_english'].apply(len)
# Out:
# 0       502
# 1       944
# 2     10014
# 3     23063
# 4     12965
#       ...
# 95      576
# 96      863
# 97      910
# 98     4262
# 99      865
# Name: document_body_english, Length: 100, dtype: int64

# %%
for i, v in enumerate(df_translated['document_body_english'].apply(len)):
    print(f"doc#{i}, char length: {v}")
# Out:
# doc#0, char length: 502
# doc#1, char length: 944
# doc#2, char length: 10014
# doc#3, char length: 23063
# doc#4, char length: 12965
# doc#5, char length: 1241
# doc#6, char length: 6352
# doc#7, char length: 932
# doc#8, char length: 37109
# doc#9, char length: 13205
# doc#10, char length: 2055
# doc#11, char length: 2202
# doc#12, char length: 411
# doc#13, char length: 2426
# doc#14, char length: 1655
# doc#15, char length: 430
# doc#16, char length: 797
# doc#17, char length: 5706
# doc#18, char length: 11550
# doc#19, char length: 816
# doc#20, char length: 13622
# doc#21, char length: 880
# doc#22, char length: 1702
# doc#23, char length: 1568
# doc#24, char length: 1090
# doc#25, char length: 1857
# doc#26, char length: 719
# doc#27, char length: 8808
# doc#28, char length: 2430
# doc#29, char length: 911
# doc#30, char length: 2975
# doc#31, char length: 7901
# doc#32, char length: 2011
# doc#33, char length: 3801
# doc#34, char length: 627
# doc#35, char length: 734
# doc#36, char length: 1823
# doc#37, char length: 1368
# doc#38, char length: 1074
# doc#39, char length: 637
# doc#40, char length: 9071
# doc#41, char length: 920
# doc#42, char length: 18066
# doc#43, char length: 1290
# doc#44, char length: 5067
# doc#45, char length: 734
# doc#46, char length: 381
# doc#47, char length: 14563
# doc#48, char length: 1624
# doc#49, char length: 770
# doc#50, char length: 547
# doc#51, char length: 1049
# doc#52, char length: 1139
# doc#53, char length: 920
# doc#54, char length: 809
# doc#55, char length: 1845
# doc#56, char length: 1300
# doc#57, char length: 602
# doc#58, char length: 559
# doc#59, char length: 897
# doc#60, char length: 16714
# doc#61, char length: 42405
# doc#62, char length: 7083
# doc#63, char length: 615
# doc#64, char length: 2253
# doc#65, char length: 772
# doc#66, char length: 611
# doc#67, char length: 48359
# doc#68, char length: 4078
# doc#69, char length: 21740
# doc#70, char length: 1396
# doc#71, char length: 1076
# doc#72, char length: 1250
# doc#73, char length: 16019
# doc#74, char length: 7910
# doc#75, char length: 1456
# doc#76, char length: 1582
# doc#77, char length: 2673
# doc#78, char length: 1961
# doc#79, char length: 1235
# doc#80, char length: 49284
# doc#81, char length: 16023
# doc#82, char length: 1795
# doc#83, char length: 549
# doc#84, char length: 399
# doc#85, char length: 1372
# doc#86, char length: 46315
# doc#87, char length: 3612
# doc#88, char length: 18055
# doc#89, char length: 328
# doc#90, char length: 1993
# doc#91, char length: 1149
# doc#92, char length: 22049
# doc#93, char length: 2679
# doc#94, char length: 46841
# doc#95, char length: 576
# doc#96, char length: 863
# doc#97, char length: 910
# doc#98, char length: 4262
# doc#99, char length: 865

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>⚠️ Info:</b> Since English language has longer words than Hebrew, translated document can exceed the max Excel cell length of 32768 chracters, to avoid text truncation - we need to split the text into multiple columns.
# </div>

# %%
df_trans_split = split_df_column(df_translated, col='document_body_english')

# %% [markdown]
# Before split

# %%
df_translated[60:70]
# Out:
#    case_number                                     procedure_name   case_date  \
# 60     8970/15               ע"פ 8970/15 אחמד עיסא נ. מדינת ישראל  2016-11-07
# 61      319/21                                         ע"פ 319/21  2022-04-10
# 62     1494/07            ע"פ 1494/07 ג'ואד אבו כפ נ. מדינת ישראל  2008-06-02
# 63      953/14  ע"א 953/14 מ.ע.א השקעות בע"מ נ. המועצה המקומית...  2014-05-18
# 64     8940/20    ע"א 8940/20 עמותת ישיבת אהל יוספ נ. רשמ העמותות  2021-01-07
# 65     7209/22                                        ע"פ 7209/22  2022-12-25
# 66     8361/17               ע"פ 8361/17 חליל עומר נ. מדינת ישראל  2018-07-11
# 67    11628/05  ע"א 11628/05 אליהו חברה לביטוח בע"מ נ. מאגר צי...  2007-12-27
# 68     7799/10  ע"א 7799/10 אריה גולובנציק נ. מנהל מיסוי מקרקע...  2010-12-15
# 69     2542/19  ע"פ 2542/19 ג'רמי ריצ'רד טוויל נ. פרקליטות המדינה  2019-12-03
#
#                                             case_link  \
# 60  https://supremedecisions.court.gov.il/Verdicts...
# 61  https://supremedecisions.court.gov.il/Verdicts...
# 62  https://supremedecisions.court.gov.il/Verdicts...
# 63  https://supremedecisions.court.gov.il/Verdicts...
# 64  https://supremedecisions.court.gov.il/Verdicts...
# 65  https://supremedecisions.court.gov.il/Verdicts...
# 66  https://supremedecisions.court.gov.il/Verdicts...
# 67  https://supremedecisions.court.gov.il/Verdicts...
# 68  https://supremedecisions.court.gov.il/Verdicts...
# 69  https://supremedecisions.court.gov.il/Verdicts...
#
#                                         document_body  \
# 60  פסק דין בתיק ע"פ 8970/15 בבית המשפט העליון בשב...
# 61  פסק דין בתיק ע"פ 319/21 בבית המשפט העליון בשבת...
# 62  החלטה בתיק ע"פ 1494/07 בבית המשפט העליון בשבתו...
# 63  החלטה בתיק ע"א 953/14 בבית המשפט העליון בירושל...
# 64  פסק דין בתיק ע"א 8940/20 בבית המשפט העליון ע"א...
# 65  החלטה בתיק ע"פ 7107/22 בבית המשפט העליון ע"פ 7...
# 66  פסק דין בתיק ע"פ 8361/17 בבית המשפט העליון בשב...
# 67  ['פסק דין בתיק ע"א 11628/05 בבית המשפט העליון ...
# 68  החלטה בתיק ע"א 7799/10 בבית המשפט העליון בירוש...
# 69  פסק דין בתיק ע"פ 2542/19 בבית המשפט העליון בשב...
#
#                                 document_body_english
# 60  The case of Appellant Ahmed Issa v. State of I...
# 61  In the case of Appeal No. 319/21 at the Suprem...
# 62  The decision in case No. 1494/07 at the Suprem...
# 63  The decision in Case A953/14 at the Supreme Co...
# 64  The decision in Civil Appeal No. 8940/20 at th...
# 65  The decision in Case No. 7107/22 at the Suprem...
# 66  In the case of Appeal No. 8361/17 at the Supre...
# 67  The case of Appeal No. 11628/05 at the Supreme...
# 68  In the case of Appeal No. 7799/10 at the Supre...
# 69  The Israeli Supreme Court in Criminal Appeal N...

# %% [markdown]
# After split

# %%
df_trans_split[60:70]
# Out:
#    case_number                                     procedure_name   case_date  \
# 60     8970/15               ע"פ 8970/15 אחמד עיסא נ. מדינת ישראל  2016-11-07
# 61      319/21                                         ע"פ 319/21  2022-04-10
# 62     1494/07            ע"פ 1494/07 ג'ואד אבו כפ נ. מדינת ישראל  2008-06-02
# 63      953/14  ע"א 953/14 מ.ע.א השקעות בע"מ נ. המועצה המקומית...  2014-05-18
# 64     8940/20    ע"א 8940/20 עמותת ישיבת אהל יוספ נ. רשמ העמותות  2021-01-07
# 65     7209/22                                        ע"פ 7209/22  2022-12-25
# 66     8361/17               ע"פ 8361/17 חליל עומר נ. מדינת ישראל  2018-07-11
# 67    11628/05  ע"א 11628/05 אליהו חברה לביטוח בע"מ נ. מאגר צי...  2007-12-27
# 68     7799/10  ע"א 7799/10 אריה גולובנציק נ. מנהל מיסוי מקרקע...  2010-12-15
# 69     2542/19  ע"פ 2542/19 ג'רמי ריצ'רד טוויל נ. פרקליטות המדינה  2019-12-03
#
#                                             case_link  \
# 60  https://supremedecisions.court.gov.il/Verdicts...
# 61  https://supremedecisions.court.gov.il/Verdicts...
# 62  https://supremedecisions.court.gov.il/Verdicts...
# 63  https://supremedecisions.court.gov.il/Verdicts...
# 64  https://supremedecisions.court.gov.il/Verdicts...
# 65  https://supremedecisions.court.gov.il/Verdicts...
# 66  https://supremedecisions.court.gov.il/Verdicts...
# 67  https://supremedecisions.court.gov.il/Verdicts...
# 68  https://supremedecisions.court.gov.il/Verdicts...
# 69  https://supremedecisions.court.gov.il/Verdicts...
#
#                                         document_body  \
# 60  פסק דין בתיק ע"פ 8970/15 בבית המשפט העליון בשב...
# 61  פסק דין בתיק ע"פ 319/21 בבית המשפט העליון בשבת...
# 62  החלטה בתיק ע"פ 1494/07 בבית המשפט העליון בשבתו...
# 63  החלטה בתיק ע"א 953/14 בבית המשפט העליון בירושל...
# 64  פסק דין בתיק ע"א 8940/20 בבית המשפט העליון ע"א...
# 65  החלטה בתיק ע"פ 7107/22 בבית המשפט העליון ע"פ 7...
# 66  פסק דין בתיק ע"פ 8361/17 בבית המשפט העליון בשב...
# 67  ['פסק דין בתיק ע"א 11628/05 בבית המשפט העליון ...
# 68  החלטה בתיק ע"א 7799/10 בבית המשפט העליון בירוש...
# 69  פסק דין בתיק ע"פ 2542/19 בבית המשפט העליון בשב...
#
#                                 document_body_english  \
# 60  The case of Appellant Ahmed Issa v. State of I...
# 61  In the case of Appeal No. 319/21 at the Suprem...
# 62  The decision in case No. 1494/07 at the Suprem...
# 63  The decision in Case A953/14 at the Supreme Co...
# 64  The decision in Civil Appeal No. 8940/20 at th...
# 65  The decision in Case No. 7107/22 at the Suprem...
# 66  In the case of Appeal No. 8361/17 at the Supre...
# 67  The case of Appeal No. 11628/05 at the Supreme...
# 68  In the case of Appeal No. 7799/10 at the Supre...
# 69  The Israeli Supreme Court in Criminal Appeal N...
#
#                               document_body_english_1  \
# 60  The case of Appellant Ahmed Issa v. State of I...
# 61  In the case of Appeal No. 319/21 at the Suprem...
# 62  The decision in case No. 1494/07 at the Suprem...
# 63  The decision in Case A953/14 at the Supreme Co...
# 64  The decision in Civil Appeal No. 8940/20 at th...
# 65  The decision in Case No. 7107/22 at the Suprem...
# 66  In the case of Appeal No. 8361/17 at the Supre...
# 67  The case of Appeal No. 11628/05 at the Supreme...
# 68  In the case of Appeal No. 7799/10 at the Supre...
# 69  The Israeli Supreme Court in Criminal Appeal N...
#
#                               document_body_english_2
# 60                                                NaN
# 61  court's intervention (see, among others, APP 7...
# 62                                                NaN
# 63                                                NaN
# 64                                                NaN
# 65                                                NaN
# 66                                                NaN
# 67  hould bear the full amount of the indemnificat...
# 68                                                NaN
# 69                                                NaN

# %%
df_trans_split = df_trans_split.drop(columns=['document_body_english'])

# %% [markdown]
# # Save translated data

# %%
f_path_translated = f_path.replace("processed", "translated")
save_file(df_trans_split, f_path_translated)
# Out:
# DataFrame successfully saved to data/translated_data_ar_ap_100.xlsx
